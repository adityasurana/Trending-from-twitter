# %% [markdown]
# # Notebook on Accessing Twitter

# %%
import pandas as pd

# %%
import pickle
import os

# %% [markdown]
# Here we will create a 'secret_twitter_credential.pkl' file in which our Twitter's Consumer Key, Consumer Secret, Access Token, Access Token Secret will be stored

# %% [markdown]
# Don't show this file to any one as it contains important info that can access your account, that's why we have not filled the value in Twitter['Consumer Key']=.... But you should fill accordingly to the credentials given to you after creating the twitter app(Creation of twitter app is explained in Readme.md).

# %%
if not os.path.exists('secret_twitter_credential.pkl'):
    Twitter={}
    Twitter['Consumer Key'] = ''
    Twitter['Consumer Secret'] = ''
    Twitter['Access Token'] = ''
    Twitter['Access Token Secret'] = ''
    with open('secret_twitter_credential.pkl','wb') as f:
        pickle.dump(Twitter, f)

# %% [markdown]
# Loading 'secret_twitter_credential.pkl' file:-

# %%
Twitter=pickle.load(open('secret_twitter_credential.pkl','rb'))

# %% [markdown]
# Install twitter by typing `pip install twitter` in anaconda prompt and then import it

# %%
import twitter

auth = twitter.oauth.OAuth(Twitter['Access Token'],
                           Twitter['Access Token Secret'],
                           Twitter['Consumer Key'],
                           Twitter['Consumer Secret'])

twitter_api = twitter.Twitter(auth=auth)

# %% [markdown]
# ## Getting the WOE ID for a place of interest

# %% [markdown]
# Finding the Yahoo! Where On Earth ID for a place you are interested in at:
#
# http://woeid.rosselliot.co.nz/
#
# Setting `WORLD_WOE_ID` to integer number=1:
#
# </br>
#
# Setting `LOCAL_WOE_ID` to integer number below(for me WOE_ID is of jaipur):

# %% [markdown]
# Twitter track trends using Yahoo! Where On Earth ID for each major location. For the whole world location ID = 1

# %%
WORLD_WOE_ID = 1
LOCAL_WOE_ID = 2295401

# %% [markdown]
# ## Retrieving and printing local trends
#
# using the twitter API to retrieve trends

# %% [markdown]
# Using trends.place for the twitter_api object we can get the top 50 trends for any location

# %%
local_trends = twitter_api.trends.place(_id=LOCAL_WOE_ID)
world_trends = twitter_api.trends.place(_id=WORLD_WOE_ID)

# %%
local_trends
# Out:
# [{'trends': [{'name': '#ExposeDeshDrohis',
#     'url': 'http://twitter.com/search?q=%23ExposeDeshDrohis',
#     'promoted_content': None,
#     'query': '%23ExposeDeshDrohis',
#     'tweet_volume': 52694},
#    {'name': '#BBLFinal',
#     'url': 'http://twitter.com/search?q=%23BBLFinal',
#     'promoted_content': None,
#     'query': '%23BBLFinal',
#     'tweet_volume': None},
#    {'name': '#TimeForRevenge',
#     'url': 'http://twitter.com/search?q=%23TimeForRevenge',
#     'promoted_content': None,
#     'query': '%23TimeForRevenge',
#     'tweet_volume': None},
#    {'name': '#KashmiriStudents',
#     'url': 'http://twitter.com/search?q=%23KashmiriStudents',
#     'promoted_content': None,
#     'query': '%23KashmiriStudents',
#     'tweet_volume': 10065},
#    {'name': 'Mirwaiz Umar Farooq',
#     'url': 'http://twitter.com/search?q=%22Mirwaiz+Umar+Farooq%22',
#     'promoted_content': None,
#     'query': '%22Mirwaiz+Umar+Farooq%22',
#     'tweet_volume': 14895},
#    {'name': '#UnsubscribeSonyTV',
#     'url': 'http://twitter.com/search?q=%23UnsubscribeSonyTV',
#     'promoted_content': None,
#     'query': '%23UnsubscribeSonyTV',
#     'tweet_volume': 27160},
#    {'name': 'Shabir Shah',
#     'url': 'http://twitter.com/search?q=%22Shabir+Shah%22',
#     'promoted_content': None,
#     'query': '%22Shabir+Shah%22',
#     'tweet_volume': 13406},
#    {'name': 'Bilal Lone',
#     'url': 'http://twitter.com/search?q=%22Bilal+Lone%22',
#     'promoted_content': None,
#     'query': '%22Bilal+Lone%22',
#     'tweet_volume': 13743},
#    {'name': 'Abdul Ghani Bhat',
#     'url': 'http://twitter.com/search?q=%22Abdul+Ghani+Bhat%22',
#     'promoted_content': None,
#     'query': '%22Abdul+Ghani+Bhat%22',
#     'tweet_volume': 13195},
#    {'name': 'Hashim Qureshi',
#     'url': 'http://twitter.com/search?q=%22Hashim+Qureshi%22',
#     'promoted_content': None,
#     'query': '%22Hashim+Qureshi%22',
#     'tweet_volume': 13370},
#    {'name': 'Melbourne Renegades',
#     'url': 'http://twitter.com/search?q=%22Melbourne+Renegades%22',
#     'promoted_content': None,
#     'query': '%22Melbourne+Renegades%22',
#     'tweet_volume': None},
#    {'name': 'Melbourne Stars',
#     'url': 'http://twitter.com/search?q=%22Melbourne+Stars%22',
#     'promoted_content': None,
#     'query': '%22Melbourne+Stars%22',
#     'tweet_volume': None},
#    {'name': 'Withdraw Hurriyat Facilities',
#     'url': 'http://twitter.com/search?q=%22Withdraw+Hurriyat+Facilities%22',
#     'promoted_content': None,
#     'query': '%22Withdraw+Hurriyat+Facilities%22',
#     'tweet_volume': None},
#    {'name': 'Barauni',
#     'url': 'http://twitter.com/search?q=Barauni',
#     'promoted_content': None,
#     'query': 'Barauni',
#     'tweet_volume': None},
#    {'name': 'Delhi Police Celebrated',
#     'url': 'http://twitter.com/search?q=%22Delhi+Police+Celebrated%22',
#     'promoted_content': None,
#     'query': '%22Delhi+Police+Celebrated%22',
#     'tweet_volume': None},
#    {'name': 'CK Khanna',
#     'url': 'http://twitter.com/search?q=%22CK+Khanna%22',
#     'promoted_content': None,
#     'query': '%22CK+Khanna%22',
#     'tweet_volume': None},
#    {'name': 'Geelani',
#     'url': 'http://twitter.com/search?q=Geelani',
#     'promoted_content': None,
#     'query': 'Geelani',
#     'tweet_volume': None},
#    {'name': 'Daniel Christian',
#     'url': 'http://twitter.com/search?q=%22Daniel+Christian%22',
#     'promoted_content': None,
#     'query': '%22Daniel+Christian%22',
#     'tweet_volume': None},
#    {'name': 'Heather Nauert',
#     'url': 'http://twitter.com/search?q=%22Heather+Nauert%22',
#     'promoted_content': None,
#     'query': '%22Heather+Nauert%22',
#     'tweet_volume': 24887},
#    {'name': 'BCCI',
#     'url': 'http://twitter.com/search?q=BCCI',
#     'promoted_content': None,
#     'query': 'BCCI',
#     'tweet_volume': None},
#    {'name': 'Maneswar Basumatary',
#     'url': 'http://twitter.com/search?q=%22Maneswar+Basumatary%22',
#     'promoted_content': None,
#     'query': '%22Maneswar+Basumatary%22',
#     'tweet_volume': None},
#    {'name': 'पूर्व मुख्यमंत्री',
#     'url': 'http://twitter.com/search?q=%22%E0%A4%AA%E0%A5%82%E0%A4%B0%E0%A5%8D%E0%A4%B5+%E0%A4%AE%E0%A5%81%E0%A4%96%E0%A5%8D%E0%A4%AF%E0%A4%AE%E0%A4%82%E0%A4%A4%E0%A5%8D%E0%A4%B0%E0%A5%80%22',
#     'promoted_content': None,
#     'query': '%22%E0%A4%AA%E0%A5%82%E0%A4%B0%E0%A5%8D%E0%A4%B5+%E0%A4%AE%E0%A5%81%E0%A4%96%E0%A5%8D%E0%A4%AF%E0%A4%AE%E0%A4%82%E0%A4%A4%E0%A5%8D%E0%A4%B0%E0%A5%80%22',
#     'tweet_volume': None},
#    {'name': '#MrLocalTeaser',
#     'url': 'http://twitter.com/search?q=%23MrLocalTeaser',
#     'promoted_content': None,
#     'query': '%23MrLocalTeaser',
#     'tweet_volume': 26106},
#    {'name': '#ChennaiSpartansAnthem',
#     'url': 'http://twitter.com/search?q=%23ChennaiSpartansAnthem',
#     'promoted_content': None,
#     'query': '%23ChennaiSpartansAnthem',
#     'tweet_volume': None},
#    {'name': '#RajiniMakkalMandram',
#     'url': 'http://twitter.com/search?q=%23RajiniMakkalMandram',
#     'promoted_content': None,
#     'query': '%23RajiniMakkalMandram',
#     'tweet_volume': None},
#    {'name': '#BBL08',
#     'url': 'http://twitter.com/search?q=%23BBL08',
#     'promoted_content': None,
#     'query': '%23BBL08',
#     'tweet_volume': None},
#    {'name': '#HBDSivaKarthikeyan',
#     'url': 'http://twitter.com/search?q=%23HBDSivaKarthikeyan',
#     'promoted_content': None,
#     'query': '%23HBDSivaKarthikeyan',
#     'tweet_volume': 17801},
#    {'name': '#BharatWithForces',
#     'url': 'http://twitter.com/search?q=%23BharatWithForces',
#     'promoted_content': None,
#     'query': '%23BharatWithForces',
#     'tweet_volume': 10789},
#    {'name': '#IslamAndPatriotism',
#     'url': 'http://twitter.com/search?q=%23IslamAndPatriotism',
#     'promoted_content': None,
#     'query': '%23IslamAndPatriotism',
#     'tweet_volume': 13898},
#    {'name': '#SOSKashmir',
#     'url': 'http://twitter.com/search?q=%23SOSKashmir',
#     'promoted_content': None,
#     'query': '%23SOSKashmir',
#     'tweet_volume': None},
#    {'name': '#PKMKB',
#     'url': 'http://twitter.com/search?q=%23PKMKB',
#     'promoted_content': None,
#     'query': '%23PKMKB',
#     'tweet_volume': None},
#    {'name': '#SundayThoughts',
#     'url': 'http://twitter.com/search?q=%23SundayThoughts',
#     'promoted_content': None,
#     'query': '%23SundayThoughts',
#     'tweet_volume': None},
#    {'name': '#Hurriyat',
#     'url': 'http://twitter.com/search?q=%23Hurriyat',
#     'promoted_content': None,
#     'query': '%23Hurriyat',
#     'tweet_volume': None},
#    {'name': '#SundayMotivation',
#     'url': 'http://twitter.com/search?q=%23SundayMotivation',
#     'promoted_content': None,
#     'query': '%23SundayMotivation',
#     'tweet_volume': 12187},
#    {'name': '#YSRCPBCGarjana',
#     'url': 'http://twitter.com/search?q=%23YSRCPBCGarjana',
#     'promoted_content': None,
#     'query': '%23YSRCPBCGarjana',
#     'tweet_volume': None},
#    {'name': '#HappyBirthdaySivaKarthikeyan',
#     'url': 'http://twitter.com/search?q=%23HappyBirthdaySivaKarthikeyan',
#     'promoted_content': None,
#     'query': '%23HappyBirthdaySivaKarthikeyan',
#     'tweet_volume': None},
#    {'name': '#sathyabama',
#     'url': 'http://twitter.com/search?q=%23sathyabama',
#     'promoted_content': None,
#     'query': '%23sathyabama',
#     'tweet_volume': None},
#    {'name': '#PulwamaTerrorAttacks',
#     'url': 'http://twitter.com/search?q=%23PulwamaTerrorAttacks',
#     'promoted_content': None,
#     'query': '%23PulwamaTerrorAttacks',
#     'tweet_volume': None},
#    {'name': '#HappyBirthdayABD',
#     'url': 'http://twitter.com/search?q=%23HappyBirthdayABD',
#     'promoted_content': None,
#     'query': '%23HappyBirthdayABD',
#     'tweet_volume': None},
#    {'name': '#YogiShiva',
#     'url': 'http://twitter.com/search?q=%23YogiShiva',
#     'promoted_content': None,
#     'query': '%23YogiShiva',
#     'tweet_volume': None},
#    {'name': '#SilluKaruppatti',
#     'url': 'http://twitter.com/search?q=%23SilluKaruppatti',
#     'promoted_content': None,
#     'query': '%23SilluKaruppatti',
#     'tweet_volume': None},
#    {'name': '#separatists',
#     'url': 'http://twitter.com/search?q=%23separatists',
#     'promoted_content': None,
#     'query': '%23separatists',
#     'tweet_volume': None},
#    {'name': '#sundaymorning',
#     'url': 'http://twitter.com/search?q=%23sundaymorning',
#     'promoted_content': None,
#     'query': '%23sundaymorning',
#     'tweet_volume': None},
#    {'name': '#MahaShivratri2019',
#     'url': 'http://twitter.com/search?q=%23MahaShivratri2019',
#     'promoted_content': None,
#     'query': '%23MahaShivratri2019',
#     'tweet_volume': None},
#    {'name': '#SuperstarRajinikanth',
#     'url': 'http://twitter.com/search?q=%23SuperstarRajinikanth',
#     'promoted_content': None,
#     'query': '%23SuperstarRajinikanth',
#     'tweet_volume': None},
#    {'name': '#BoxOfficeIndiaQuiz',
#     'url': 'http://twitter.com/search?q=%23BoxOfficeIndiaQuiz',
#     'promoted_content': None,
#     'query': '%23BoxOfficeIndiaQuiz',
#     'tweet_volume': None},
#    {'name': '#SundaySpecial',
#     'url': 'http://twitter.com/search?q=%23SundaySpecial',
#     'promoted_content': None,
#     'query': '%23SundaySpecial',
#     'tweet_volume': None},
#    {'name': '#TaimurAliKhan',
#     'url': 'http://twitter.com/search?q=%23TaimurAliKhan',
#     'promoted_content': None,
#     'query': '%23TaimurAliKhan',
#     'tweet_volume': None},
#    {'name': '#BhobishyoterBhoot',
#     'url': 'http://twitter.com/search?q=%23BhobishyoterBhoot',
#     'promoted_content': None,
#     'query': '%23BhobishyoterBhoot',
#     'tweet_volume': None},
#    {'name': '#SundayFunday',
#     'url': 'http://twitter.com/search?q=%23SundayFunday',
#     'promoted_content': None,
#     'query': '%23SundayFunday',
#     'tweet_volume': None}],
#   'as_of': '2019-02-17T09:41:43Z',
#   'created_at': '2019-02-17T09:35:13Z',
#   'locations': [{'name': 'Jaipur', 'woeid': 2295401}]}]

# %%
world_trends
# Out:
# [{'trends': [{'name': '#BlazeTheTrailDLSU',
#     'url': 'http://twitter.com/search?q=%23BlazeTheTrailDLSU',
#     'promoted_content': None,
#     'query': '%23BlazeTheTrailDLSU',
#     'tweet_volume': 13733},
#    {'name': '#DünyaKedilerGünü',
#     'url': 'http://twitter.com/search?q=%23D%C3%BCnyaKedilerG%C3%BCn%C3%BC',
#     'promoted_content': None,
#     'query': '%23D%C3%BCnyaKedilerG%C3%BCn%C3%BC',
#     'tweet_volume': None},
#    {'name': '#UAAPSeason81Volleyball',
#     'url': 'http://twitter.com/search?q=%23UAAPSeason81Volleyball',
#     'promoted_content': None,
#     'query': '%23UAAPSeason81Volleyball',
#     'tweet_volume': 22112},
#    {'name': '#ForTheSeniors',
#     'url': 'http://twitter.com/search?q=%23ForTheSeniors',
#     'promoted_content': None,
#     'query': '%23ForTheSeniors',
#     'tweet_volume': 13466},
#    {'name': 'DaimaTevhid ÜzerindeDuracağız',
#     'url': 'http://twitter.com/search?q=%22DaimaTevhid+%C3%9CzerindeDuraca%C4%9F%C4%B1z%22',
#     'promoted_content': None,
#     'query': '%22DaimaTevhid+%C3%9CzerindeDuraca%C4%9F%C4%B1z%22',
#     'tweet_volume': None},
#    {'name': '#pazar',
#     'url': 'http://twitter.com/search?q=%23pazar',
#     'promoted_content': None,
#     'query': '%23pazar',
#     'tweet_volume': 19796},
#    {'name': 'Ateneo',
#     'url': 'http://twitter.com/search?q=Ateneo',
#     'promoted_content': None,
#     'query': 'Ateneo',
#     'tweet_volume': 18923},
#    {'name': 'インティ',
#     'url': 'http://twitter.com/search?q=%E3%82%A4%E3%83%B3%E3%83%86%E3%82%A3',
#     'promoted_content': None,
#     'query': '%E3%82%A4%E3%83%B3%E3%83%86%E3%82%A3',
#     'tweet_volume': 33310},
#    {'name': '岩橋くん',
#     'url': 'http://twitter.com/search?q=%E5%B2%A9%E6%A9%8B%E3%81%8F%E3%82%93',
#     'promoted_content': None,
#     'query': '%E5%B2%A9%E6%A9%8B%E3%81%8F%E3%82%93',
#     'tweet_volume': None},
#    {'name': 'La Salle',
#     'url': 'http://twitter.com/search?q=%22La+Salle%22',
#     'promoted_content': None,
#     'query': '%22La+Salle%22',
#     'tweet_volume': 12647},
#    {'name': 'ONE BIG FIGHT',
#     'url': 'http://twitter.com/search?q=%22ONE+BIG+FIGHT%22',
#     'promoted_content': None,
#     'query': '%22ONE+BIG+FIGHT%22',
#     'tweet_volume': None},
#    {'name': 'Dela Cruz',
#     'url': 'http://twitter.com/search?q=%22Dela+Cruz%22',
#     'promoted_content': None,
#     'query': '%22Dela+Cruz%22',
#     'tweet_volume': None},
#    {'name': '玄樹くん',
#     'url': 'http://twitter.com/search?q=%E7%8E%84%E6%A8%B9%E3%81%8F%E3%82%93',
#     'promoted_content': None,
#     'query': '%E7%8E%84%E6%A8%B9%E3%81%8F%E3%82%93',
#     'tweet_volume': None},
#    {'name': 'ADMU',
#     'url': 'http://twitter.com/search?q=ADMU',
#     'promoted_content': None,
#     'query': 'ADMU',
#     'tweet_volume': None},
#    {'name': 'Adamson',
#     'url': 'http://twitter.com/search?q=Adamson',
#     'promoted_content': None,
#     'query': 'Adamson',
#     'tweet_volume': None},
#    {'name': '活動再開',
#     'url': 'http://twitter.com/search?q=%E6%B4%BB%E5%8B%95%E5%86%8D%E9%96%8B',
#     'promoted_content': None,
#     'query': '%E6%B4%BB%E5%8B%95%E5%86%8D%E9%96%8B',
#     'tweet_volume': None},
#    {'name': 'フェブラリーS',
#     'url': 'http://twitter.com/search?q=%E3%83%95%E3%82%A7%E3%83%96%E3%83%A9%E3%83%AA%E3%83%BCS',
#     'promoted_content': None,
#     'query': '%E3%83%95%E3%82%A7%E3%83%96%E3%83%A9%E3%83%AA%E3%83%BCS',
#     'tweet_volume': 21692},
#    {'name': 'Ponggay',
#     'url': 'http://twitter.com/search?q=Ponggay',
#     'promoted_content': None,
#     'query': 'Ponggay',
#     'tweet_volume': None},
#    {'name': 'Eya Laure',
#     'url': 'http://twitter.com/search?q=%22Eya+Laure%22',
#     'promoted_content': None,
#     'query': '%22Eya+Laure%22',
#     'tweet_volume': None},
#    {'name': 'Gandler',
#     'url': 'http://twitter.com/search?q=Gandler',
#     'promoted_content': None,
#     'query': 'Gandler',
#     'tweet_volume': None},
#    {'name': 'アイナナ4部',
#     'url': 'http://twitter.com/search?q=%E3%82%A2%E3%82%A4%E3%83%8A%E3%83%8A4%E9%83%A8',
#     'promoted_content': None,
#     'query': '%E3%82%A2%E3%82%A4%E3%83%8A%E3%83%8A4%E9%83%A8',
#     'tweet_volume': 23207},
#    {'name': 'BANANAFISHの登場人物',
#     'url': 'http://twitter.com/search?q=BANANAFISH%E3%81%AE%E7%99%BB%E5%A0%B4%E4%BA%BA%E7%89%A9',
#     'promoted_content': None,
#     'query': 'BANANAFISH%E3%81%AE%E7%99%BB%E5%A0%B4%E4%BA%BA%E7%89%A9',
#     'tweet_volume': None},
#    {'name': '#六弥ナギのパスポートを燃やせ',
#     'url': 'http://twitter.com/search?q=%23%E5%85%AD%E5%BC%A5%E3%83%8A%E3%82%AE%E3%81%AE%E3%83%91%E3%82%B9%E3%83%9D%E3%83%BC%E3%83%88%E3%82%92%E7%87%83%E3%82%84%E3%81%9B',
#     'promoted_content': None,
#     'query': '%23%E5%85%AD%E5%BC%A5%E3%83%8A%E3%82%AE%E3%81%AE%E3%83%91%E3%82%B9%E3%83%9D%E3%83%BC%E3%83%88%E3%82%92%E7%87%83%E3%82%84%E3%81%9B',
#     'tweet_volume': None},
#    {'name': '#FelizDomingo',
#     'url': 'http://twitter.com/search?q=%23FelizDomingo',
#     'promoted_content': None,
#     'query': '%23FelizDomingo',
#     'tweet_volume': None},
#    {'name': '#الحياه_تحتاج_منا',
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D8%AD%D9%8A%D8%A7%D9%87_%D8%AA%D8%AD%D8%AA%D8%A7%D8%AC_%D9%85%D9%86%D8%A7',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D8%AD%D9%8A%D8%A7%D9%87_%D8%AA%D8%AD%D8%AA%D8%A7%D8%AC_%D9%85%D9%86%D8%A7',
#     'tweet_volume': 28274},
#    {'name': '#terimakasihmantan',
#     'url': 'http://twitter.com/search?q=%23terimakasihmantan',
#     'promoted_content': None,
#     'query': '%23terimakasihmantan',
#     'tweet_volume': None},
#    {'name': '#BBLFinal',
#     'url': 'http://twitter.com/search?q=%23BBLFinal',
#     'promoted_content': None,
#     'query': '%23BBLFinal',
#     'tweet_volume': None},
#    {'name': '#神様が3行で説明してくれる診断',
#     'url': 'http://twitter.com/search?q=%23%E7%A5%9E%E6%A7%98%E3%81%8C3%E8%A1%8C%E3%81%A7%E8%AA%AC%E6%98%8E%E3%81%97%E3%81%A6%E3%81%8F%E3%82%8C%E3%82%8B%E8%A8%BA%E6%96%AD',
#     'promoted_content': None,
#     'query': '%23%E7%A5%9E%E6%A7%98%E3%81%8C3%E8%A1%8C%E3%81%A7%E8%AA%AC%E6%98%8E%E3%81%97%E3%81%A6%E3%81%8F%E3%82%8C%E3%82%8B%E8%A8%BA%E6%96%AD',
#     'tweet_volume': 21448},
#    {'name': '#UAAP81WomensVolleyball',
#     'url': 'http://twitter.com/search?q=%23UAAP81WomensVolleyball',
#     'promoted_content': None,
#     'query': '%23UAAP81WomensVolleyball',
#     'tweet_volume': None},
#    {'name': '#KimTzuyuReturns',
#     'url': 'http://twitter.com/search?q=%23KimTzuyuReturns',
#     'promoted_content': None,
#     'query': '%23KimTzuyuReturns',
#     'tweet_volume': 17467},
#    {'name': '#ExposeDeshDrohis',
#     'url': 'http://twitter.com/search?q=%23ExposeDeshDrohis',
#     'promoted_content': None,
#     'query': '%23ExposeDeshDrohis',
#     'tweet_volume': 52694},
#    {'name': '#BTSinFukuoka_D2',
#     'url': 'http://twitter.com/search?q=%23BTSinFukuoka_D2',
#     'promoted_content': None,
#     'query': '%23BTSinFukuoka_D2',
#     'tweet_volume': 45920},
#    {'name': '#GoUSTe',
#     'url': 'http://twitter.com/search?q=%23GoUSTe',
#     'promoted_content': None,
#     'query': '%23GoUSTe',
#     'tweet_volume': None},
#    {'name': '#TwitartirAçılldı',
#     'url': 'http://twitter.com/search?q=%23TwitartirA%C3%A7%C4%B1lld%C4%B1',
#     'promoted_content': None,
#     'query': '%23TwitartirA%C3%A7%C4%B1lld%C4%B1',
#     'tweet_volume': None},
#    {'name': '#ElimdeOlsa',
#     'url': 'http://twitter.com/search?q=%23ElimdeOlsa',
#     'promoted_content': None,
#     'query': '%23ElimdeOlsa',
#     'tweet_volume': None},
#    {'name': '#岩橋玄樹',
#     'url': 'http://twitter.com/search?q=%23%E5%B2%A9%E6%A9%8B%E7%8E%84%E6%A8%B9',
#     'promoted_content': None,
#     'query': '%23%E5%B2%A9%E6%A9%8B%E7%8E%84%E6%A8%B9',
#     'tweet_volume': 12673},
#    {'name': '#SundayThoughts',
#     'url': 'http://twitter.com/search?q=%23SundayThoughts',
#     'promoted_content': None,
#     'query': '%23SundayThoughts',
#     'tweet_volume': None},
#    {'name': '#SundayMotivation',
#     'url': 'http://twitter.com/search?q=%23SundayMotivation',
#     'promoted_content': None,
#     'query': '%23SundayMotivation',
#     'tweet_volume': 12187},
#    {'name': '#Bellator216',
#     'url': 'http://twitter.com/search?q=%23Bellator216',
#     'promoted_content': None,
#     'query': '%23Bellator216',
#     'tweet_volume': 17480},
#    {'name': '#anipoke',
#     'url': 'http://twitter.com/search?q=%23anipoke',
#     'promoted_content': None,
#     'query': '%23anipoke',
#     'tweet_volume': None},
#    {'name': '#صباح_الاحد',
#     'url': 'http://twitter.com/search?q=%23%D8%B5%D8%A8%D8%A7%D8%AD_%D8%A7%D9%84%D8%A7%D8%AD%D8%AF',
#     'promoted_content': None,
#     'query': '%23%D8%B5%D8%A8%D8%A7%D8%AD_%D8%A7%D9%84%D8%A7%D8%AD%D8%AF',
#     'tweet_volume': 14279},
#    {'name': '#UAAPSeason81WomensVolleyball',
#     'url': 'http://twitter.com/search?q=%23UAAPSeason81WomensVolleyball',
#     'promoted_content': None,
#     'query': '%23UAAPSeason81WomensVolleyball',
#     'tweet_volume': None},
#    {'name': '#EVDLV',
#     'url': 'http://twitter.com/search?q=%23EVDLV',
#     'promoted_content': None,
#     'query': '%23EVDLV',
#     'tweet_volume': 20613},
#    {'name': '#DebatPintarJokowi',
#     'url': 'http://twitter.com/search?q=%23DebatPintarJokowi',
#     'promoted_content': None,
#     'query': '%23DebatPintarJokowi',
#     'tweet_volume': 66273},
#    {'name': '#17febbraio',
#     'url': 'http://twitter.com/search?q=%2317febbraio',
#     'promoted_content': None,
#     'query': '%2317febbraio',
#     'tweet_volume': None},
#    {'name': '#SoyLunaExposedParty',
#     'url': 'http://twitter.com/search?q=%23SoyLunaExposedParty',
#     'promoted_content': None,
#     'query': '%23SoyLunaExposedParty',
#     'tweet_volume': 85261},
#    {'name': '#CrownPrinceinPakistan',
#     'url': 'http://twitter.com/search?q=%23CrownPrinceinPakistan',
#     'promoted_content': None,
#     'query': '%23CrownPrinceinPakistan',
#     'tweet_volume': 13378},
#    {'name': '#ImACelebrityAU',
#     'url': 'http://twitter.com/search?q=%23ImACelebrityAU',
#     'promoted_content': None,
#     'query': '%23ImACelebrityAU',
#     'tweet_volume': None},
#    {'name': '#wnlopzondag',
#     'url': 'http://twitter.com/search?q=%23wnlopzondag',
#     'promoted_content': None,
#     'query': '%23wnlopzondag',
#     'tweet_volume': None},
#    {'name': '#PARKJIHOONinBANGKOK',
#     'url': 'http://twitter.com/search?q=%23PARKJIHOONinBANGKOK',
#     'promoted_content': None,
#     'query': '%23PARKJIHOONinBANGKOK',
#     'tweet_volume': 176569}],
#   'as_of': '2019-02-17T09:41:48Z',
#   'created_at': '2019-02-17T09:35:11Z',
#   'locations': [{'name': 'Worldwide', 'woeid': 1}]}]

# %%
list_of_trends_world = [trend["name"] for trend in world_trends[0]['trends']]

# %% [markdown]
# Displaying trending in twitter for whole world (top 50)

# %%
list_of_trends_world
# Out:
# ['#BlazeTheTrailDLSU',
#  '#DünyaKedilerGünü',
#  '#UAAPSeason81Volleyball',
#  '#ForTheSeniors',
#  'DaimaTevhid ÜzerindeDuracağız',
#  '#pazar',
#  'Ateneo',
#  'インティ',
#  '岩橋くん',
#  'La Salle',
#  'ONE BIG FIGHT',
#  'Dela Cruz',
#  '玄樹くん',
#  'ADMU',
#  'Adamson',
#  '活動再開',
#  'フェブラリーS',
#  'Ponggay',
#  'Eya Laure',
#  'Gandler',
#  'アイナナ4部',
#  'BANANAFISHの登場人物',
#  '#六弥ナギのパスポートを燃やせ',
#  '#FelizDomingo',
#  '#الحياه_تحتاج_منا',
#  '#terimakasihmantan',
#  '#BBLFinal',
#  '#神様が3行で説明してくれる診断',
#  '#UAAP81WomensVolleyball',
#  '#KimTzuyuReturns',
#  '#ExposeDeshDrohis',
#  '#BTSinFukuoka_D2',
#  '#GoUSTe',
#  '#TwitartirAçılldı',
#  '#ElimdeOlsa',
#  '#岩橋玄樹',
#  '#SundayThoughts',
#  '#SundayMotivation',
#  '#Bellator216',
#  '#anipoke',
#  '#صباح_الاحد',
#  '#UAAPSeason81WomensVolleyball',
#  '#EVDLV',
#  '#DebatPintarJokowi',
#  '#17febbraio',
#  '#SoyLunaExposedParty',
#  '#CrownPrinceinPakistan',
#  '#ImACelebrityAU',
#  '#wnlopzondag',
#  '#PARKJIHOONinBANGKOK']

# %%
list_of_trends = [trend["name"] for trend in local_trends[0]['trends']]

# %% [markdown]
# Displaying trending in twitter for jaipur(top 50)

# %%
list_of_trends
# Out:
# ['#ExposeDeshDrohis',
#  '#BBLFinal',
#  '#TimeForRevenge',
#  '#KashmiriStudents',
#  'Mirwaiz Umar Farooq',
#  '#UnsubscribeSonyTV',
#  'Shabir Shah',
#  'Bilal Lone',
#  'Abdul Ghani Bhat',
#  'Hashim Qureshi',
#  'Melbourne Renegades',
#  'Melbourne Stars',
#  'Withdraw Hurriyat Facilities',
#  'Barauni',
#  'Delhi Police Celebrated',
#  'CK Khanna',
#  'Geelani',
#  'Daniel Christian',
#  'Heather Nauert',
#  'BCCI',
#  'Maneswar Basumatary',
#  'पूर्व मुख्यमंत्री',
#  '#MrLocalTeaser',
#  '#ChennaiSpartansAnthem',
#  '#RajiniMakkalMandram',
#  '#BBL08',
#  '#HBDSivaKarthikeyan',
#  '#BharatWithForces',
#  '#IslamAndPatriotism',
#  '#SOSKashmir',
#  '#PKMKB',
#  '#SundayThoughts',
#  '#Hurriyat',
#  '#SundayMotivation',
#  '#YSRCPBCGarjana',
#  '#HappyBirthdaySivaKarthikeyan',
#  '#sathyabama',
#  '#PulwamaTerrorAttacks',
#  '#HappyBirthdayABD',
#  '#YogiShiva',
#  '#SilluKaruppatti',
#  '#separatists',
#  '#sundaymorning',
#  '#MahaShivratri2019',
#  '#SuperstarRajinikanth',
#  '#BoxOfficeIndiaQuiz',
#  '#SundaySpecial',
#  '#TaimurAliKhan',
#  '#BhobishyoterBhoot',
#  '#SundayFunday']

# %% [markdown]
# ## Collecting search results
#
# Now we are executing a search on Twitter for the most popular trend and filtering step to remove duplicate results.
#
# Setting the `topic_in_world` variable to the most popular trend in the list we retrieved in list_of_trends_world:-

# %%
topic_in_world = list_of_trends_world[0] # 1st element in list_of_trends_world
number = 100  #number of records you want to get, here=100

search_results_in_world = twitter_api.search.tweets(q=topic_in_world, count=number)

statuses_in_world = search_results_in_world['statuses']

# %% [markdown]
# Getting the bunch of records for each tweet in JSON format:-

# %%
statuses_in_world
# Out:
# [{'created_at': 'Sun Feb 17 09:41:36 +0000 2019',
#   'id': 1097068536088809472,
#   'id_str': '1097068536088809472',
#   'text': 'Jolina Dela Cruz parang bagong Ara Galang hmmm.... #BlazeTheTrailDLSU',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'BlazeTheTrailDLSU',
#      'indices': [51, 69]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': []},
#   'metadata': {'iso_language_code': 'tl', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2751496261,
#    'id_str': '2751496261',
#    'name': 'joyz',
#    'screen_name': 'jycdsbl',
#    'location': "noah's",
#    'description': '\u200f\u200fروح بائسة',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 219,
#    'friends_count': 215,
#    'listed_count': 0,
#    'created_at': 'Thu Aug 21 06:20:29 +0000 2014',
#    'favourites_count': 19440,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 18943,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5ABB5',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme11/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme11/bg.gif',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1095733058341265408/Hx1_6M1S_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1095733058341265408/Hx1_6M1S_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2751496261/1550078025',
#    'profile_link_color': 'ABB8C2',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': '7AC3EE',
#    'profile_text_color': '3D1957',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'tl'},
#  {'created_at': 'Sun Feb 17 09:41:35 +0000 2019',
#   'id': 1097068534847270912,
#   'id_str': '1097068534847270912',
#   'text': 'Nakikita ko si Ara Galang kay jolina dela cruz!!😱\n#BlazeTheTrailDLSU',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'BlazeTheTrailDLSU',
#      'indices': [50, 68]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': []},
#   'metadata': {'iso_language_code': 'tl', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 4787913852,
#    'id_str': '4787913852',
#    'name': 'Maria anghela',
#    'screen_name': 'GelaGuno',
#    'location': 'neverland',
#    'description': 'Isaiah 41:13💖\n\nsum ➕',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 507,
#    'friends_count': 818,
#    'listed_count': 0,
#    'created_at': 'Wed Jan 20 09:20:51 +0000 2016',
#    'favourites_count': 6674,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 4403,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1040037642044227584/b95KeftQ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1040037642044227584/b95KeftQ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4787913852/1550280716',
#    'profile_link_color': '7FDBB6',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'tl'},
#  {'created_at': 'Sun Feb 17 09:41:35 +0000 2019',
#   'id': 1097068534004215808,
#   'id_str': '1097068534004215808',
#   'text': 'RT @MissEverywhere_: Why #BlazeTheTrailDLSU?\n\nPlayers come and go. This year, we witness the rise of new and young players ready to make th…',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'BlazeTheTrailDLSU',
#      'indices': [25, 43]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'MissEverywhere_',
#      'name': 'For The Lady Spikers ➳',
#      'id': 708682892637904897,
#      'id_str': '708682892637904897',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1925975990,
#    'id_str': '1925975990',
#    'name': 'Timothy Angel 🌈💪🏻',
#    'screen_name': 'mrtimothyangel',
#    'location': 'Manila City, National Capital Region',
#    'description': 'God & Family is everything “I always accept the things that I couldn’t change” ❤️',
#    'url': 'https://t.co/9cKgdsD0DT',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/9cKgdsD0DT',
#        'expanded_url': 'http://facebook.com/AngelTimmiethy',
#        'display_url': 'facebook.com/AngelTimmiethy',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 309,
#    'friends_count': 427,
#    'listed_count': 0,
#    'created_at': 'Wed Oct 02 07:10:02 +0000 2013',
#    'favourites_count': 2170,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 8141,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1079415563221225472/Fba-e9oM_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1079415563221225472/Fba-e9oM_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1925975990/1546187701',
#    'profile_link_color': '2F3CED',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat Feb 16 12:36:02 +0000 2019',
#    'id': 1096750048736567296,
#    'id_str': '1096750048736567296',
#    'text': 'Why #BlazeTheTrailDLSU?\n\nPlayers come and go. This year, we witness the rise of new and young players ready to make… https://t.co/GEGA81mbPt',
#    'truncated': True,
#    'entities': {'hashtags': [{'text': 'BlazeTheTrailDLSU',
#       'indices': [4, 22]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/GEGA81mbPt',
#       'expanded_url': 'https://twitter.com/i/web/status/1096750048736567296',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 708682892637904897,
#     'id_str': '708682892637904897',
#     'name': 'For The Lady Spikers ➳',
#     'screen_name': 'MissEverywhere_',
#     'location': 'De La Salle University',
#     'description': 'UAAP Best Libero | PSL Best Libero | UAAP MVP | PSL MVP | One of Asia’s finest | Miss Volleyball 2017 | Miss Everywhere 🇵🇭 @dawn_macandili',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 6606,
#     'friends_count': 341,
#     'listed_count': 19,
#     'created_at': 'Sat Mar 12 15:55:43 +0000 2016',
#     'favourites_count': 4280,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5409,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1097000222184468482/Y7O7JRP1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1097000222184468482/Y7O7JRP1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/708682892637904897/1490092876',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 411,
#    'favorite_count': 813,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 411,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Feb 17 09:41:35 +0000 2019',
#   'id': 1097068532532039682,
#   'id_str': '1097068532532039682',
#   'text': 'Aceee for JDC #BlazeTheTrailDLSU',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'BlazeTheTrailDLSU',
#      'indices': [14, 32]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 3251070396,
#    'id_str': '3251070396',
#    'name': 'Corrine✨',
#    'screen_name': 'treenarciga',
#    'location': 'Concepcion Tarlac ',
#    'description': '➖18 • ANIMO • ABM',
#    'url': 'https://t.co/KUoo8q9RJd',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/KUoo8q9RJd',
#        'expanded_url': 'https://www.instagram.com/treenarciga/',
#        'display_url': 'instagram.com/treenarciga/',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 545,
#    'friends_count': 437,
#    'listed_count': 1,
#    'created_at': 'Sun Jun 21 01:27:05 +0000 2015',
#    'favourites_count': 31528,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 16953,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/942056034390106112/xBSfvUeJ_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/942056034390106112/xBSfvUeJ_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3251070396/1545311094',
#    'profile_link_color': '19CF86',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Feb 17 09:41:35 +0000 2019',
#   'id': 1097068531500249088,
#   'id_str': '1097068531500249088',
#   'text': 'RT @daddy_thom: OKAY DONT GET ME WRONG GUYS DI NAMAN SA NAGCOCOMPARE AKO PERO SHET NAKAKA EXCITE LANG KASI AT NAKAKATUWA PANOORIN SI JOLINA…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'daddy_thom',
#      'name': '🕊',
#      'id': 562844484,
#      'id_str': '562844484',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'tl', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 3142212391,
#    'id_str': '3142212391',
#    'name': 'ALYSSA',
#    'screen_name': 'galangthegreat',
#    'location': '',
#    'description': 'fight for the green and white 🏹💚',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1351,
#    'friends_count': 1597,
#    'listed_count': 12,
#    'created_at': 'Mon Apr 06 15:24:54 +0000 2015',
#    'favourites_count': 10433,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 32593,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1083380688336781312/MNmznle__normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1083380688336781312/MNmznle__normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3142212391/1545321800',
#    'profile_link_color': '19CF86',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Feb 17 09:26:02 +0000 2019',
#    'id': 1097064618352996352,
#    'id_str': '1097064618352996352',
#    'text': 'OKAY DONT GET ME WRONG GUYS DI NAMAN SA NAGCOCOMPARE AKO PERO SHET NAKAKA EXCITE LANG KASI AT NAKAKATUWA PANOORIN S… https://t.co/4JEwWjUJLV',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/4JEwWjUJLV',
#       'expanded_url': 'https://twitter.com/i/web/status/1097064618352996352',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'tl', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 562844484,
#     'id_str': '562844484',
#     'name': '🕊',
#     'screen_name': 'daddy_thom',
#     'location': '',
#     'description': 'fan account',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 6116,
#     'friends_count': 107,
#     'listed_count': 30,
#     'created_at': 'Wed Apr 25 10:15:31 +0000 2012',
#     'favourites_count': 53642,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 85311,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1097044457319362560/3_CYzwsr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1097044457319362560/3_CYzwsr_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/562844484/1523128715',
#     'profile_link_color': 'F5ABB5',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 52,
#    'favorite_count': 87,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'tl'},
#   'is_quote_status': False,
#   'retweet_count': 52,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'tl'},
#  {'created_at': 'Sun Feb 17 09:41:34 +0000 2019',
#   'id': 1097068529554059264,
#   'id_str': '1097068529554059264',
#   'text': 'CHAMPS\n#BlazeTheTrailDLSU #UAAPSeason81Volleyball https://t.co/Gkdl4VHLnb',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'BlazeTheTrailDLSU', 'indices': [7, 25]},
#     {'text': 'UAAPSeason81Volleyball', 'indices': [26, 49]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/Gkdl4VHLnb',
#      'expanded_url': 'https://twitter.com/abscbnsports/status/1097066122405265409',
#      'display_url': 'twitter.com/abscbnsports/s…',
#      'indices': [50, 73]}]},
#   'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 4145819599,
#    'id_str': '4145819599',
#    'name': 'Thlyn;🌹',
#    'screen_name': 'Ruruthv',
#    'location': 'Registered Social Worker 🌼',
#    'description': '2459, RSW ❣️ Cast all your anxiety on him because he cares for you. -Peter 5:7 🙏',
#    'url': 'https://t.co/7sWtsB9i67',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/7sWtsB9i67',
#        'expanded_url': 'http://instagram.com/ruruthv',
#        'display_url': 'instagram.com/ruruthv',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 682,
#    'friends_count': 580,
#    'listed_count': 0,
#    'created_at': 'Fri Nov 06 12:00:30 +0000 2015',
#    'favourites_count': 6691,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 11597,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1096277201907965952/JzvN-4UM_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1096277201907965952/JzvN-4UM_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/4145819599/1549980197',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '001f00b31958ca79',
#    'url': 'https://api.twitter.com/1.1/geo/id/001f00b31958ca79.json',
#    'place_type': 'city',
#    'name': 'Zamboanga City',
#    'full_name': 'Zamboanga City, Zamboanga Peninsula',
#    'country_code': 'PH',
#    'country': 'Republic of the Philippines',
#    'contained_within': [],
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[121.8994113, 6.880958],
#       [122.3950718, 6.880958],
#       [122.3950718, 7.4699884],
#       [121.8994113, 7.4699884]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': True,
#   'quoted_status_id': 1097066122405265409,
#   'quoted_status_id_str': '1097066122405265409',
#   'quoted_status': {'created_at': 'Sun Feb 17 09:32:00 +0000 2019',
#    'id': 1097066122405265409,
#    'id_str': '1097066122405265409',
#    'text': 'MVPs in the house 🏆 #UAAPSeason81Volleyball https://t.co/fkFLeaTcn1',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'UAAPSeason81Volleyball',
#       'indices': [20, 43]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1097066100125122562,
#       'id_str': '1097066100125122562',
#       'indices': [44, 67],
#       'media_url': 'http://pbs.twimg.com/tweet_video_thumb/DzmPzjkUwAIFuu2.jpg',
#       'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/DzmPzjkUwAIFuu2.jpg',
#       'url': 'https://t.co/fkFLeaTcn1',
#       'display_url': 'pic.twitter.com/fkFLeaTcn1',
#       'expanded_url': 'https://twitter.com/abscbnsports/status/1097066122405265409/photo/1',
#       'type': 'photo',
#       'sizes': {'medium': {'w': 480, 'h': 270, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 480, 'h': 270, 'resize': 'fit'},
#        'large': {'w': 480, 'h': 270, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1097066100125122562,
#       'id_str': '1097066100125122562',
#       'indices': [44, 67],
#       'media_url': 'http://pbs.twimg.com/tweet_video_thumb/DzmPzjkUwAIFuu2.jpg',
#       'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/DzmPzjkUwAIFuu2.jpg',
#       'url': 'https://t.co/fkFLeaTcn1',
#       'display_url': 'pic.twitter.com/fkFLeaTcn1',
#       'expanded_url': 'https://twitter.com/abscbnsports/status/1097066122405265409/photo/1',
#       'type': 'animated_gif',
#       'sizes': {'medium': {'w': 480, 'h': 270, 'resize': 'fit'},
#        'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'small': {'w': 480, 'h': 270, 'resize': 'fit'},
#        'large': {'w': 480, 'h': 270, 'resize': 'fit'}},
#       'video_info': {'aspect_ratio': [16, 9],
#        'variants': [{'bitrate': 0,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/tweet_video/DzmPzjkUwAIFuu2.mp4'}]}}]},
#    'metadata': {'iso_language_code': 'fr', 'result_type': 'recent'},
#    'source': '<a href="http://snappytv.com" rel="nofollow">SnappyTV.com</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 106344746,
#     'id_str': '106344746',
#     'name': 'ABS-CBN Sports',
#     'screen_name': 'abscbnsports',
#     'location': 'Quezon City, Philippines',
#     'description': 'In the service of the Filipino sports fan, worldwide.',
#     'url': 'https://t.co/zGZlmzwa2I',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/zGZlmzwa2I',
#         'expanded_url': 'http://sports.abs-cbn.com',
#         'display_url': 'sports.abs-cbn.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1177331,
#     'friends_count': 370,
#     'listed_count': 887,
#     'created_at': 'Tue Jan 19 07:35:37 +0000 2010',
#     'favourites_count': 354,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 270965,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '022330',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#     'profile_background_tile': True,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1083573607543001093/UnGMBKjy_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1083573607543001093/UnGMBKjy_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/106344746/1550386118',
#     'profile_link_color': '0084B4',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': 'C0DFEC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 174,
#    'favorite_count': 625,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'fr'},
#  {'created_at': 'Sun Feb 17 09:41:33 +0000 2019',
#   'id': 1097068522641985537,
#   'id_str': '1097068522641985537',
#   'text': 'ANOTHER ACE FOR JOLINA DELA CRUZ 💚 #BlazeTheTrailDLSU',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'BlazeTheTrailDLSU',
#      'indices': [35, 53]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 862422354344857601,
#    'id_str': '862422354344857601',
#    'name': 'Jolina',
#    'screen_name': 'JolinaOFP',
#    'location': 'Taft',
#    'description': 'Made to support Jolina Dela Cruz and the Lady Spikers 💚 JDC Official Fan Page.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 748,
#    'friends_count': 247,
#    'listed_count': 2,
#    'created_at': 'Wed May 10 21:41:27 +0000 2017',
#    'favourites_count': 2152,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1305,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1092071805248892933/HAHo20rP_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1092071805248892933/HAHo20rP_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/862422354344857601/1546700910',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'pt'},
#  {'created_at': 'Sun Feb 17 09:41:32 +0000 2019',
#   'id': 1097068521345888256,
#   'id_str': '1097068521345888256',
#   'text': "Let's go Lady Spikers!!!!! 💚💚 #BlazeTheTrailDLSU https://t.co/44j7sjggx4",
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'BlazeTheTrailDLSU',
#      'indices': [30, 48]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [],
#    'media': [{'id': 1097068485190897665,
#      'id_str': '1097068485190897665',
#      'indices': [49, 72],
#      'media_url': 'http://pbs.twimg.com/media/DzmR-YoUUAEC1vD.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DzmR-YoUUAEC1vD.jpg',
#      'url': 'https://t.co/44j7sjggx4',
#      'display_url': 'pic.twitter.com/44j7sjggx4',
#      'expanded_url': 'https://twitter.com/gyrabarroga/status/1097068521345888256/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1536, 'h': 2048, 'resize': 'fit'},
#       'medium': {'w': 900, 'h': 1200, 'resize': 'fit'},
#       'small': {'w': 510, 'h': 680, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1097068485190897665,
#      'id_str': '1097068485190897665',
#      'indices': [49, 72],
#      'media_url': 'http://pbs.twimg.com/media/DzmR-YoUUAEC1vD.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/DzmR-YoUUAEC1vD.jpg',
#      'url': 'https://t.co/44j7sjggx4',
#      'display_url': 'pic.twitter.com/44j7sjggx4',
#      'expanded_url': 'https://twitter.com/gyrabarroga/status/1097068521345888256/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 1536, 'h': 2048, 'resize': 'fit'},
#       'medium': {'w': 900, 'h': 1200, 'resize': 'fit'},
#       'small': {'w': 510, 'h': 680, 'resize': 'fit'}}}]},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 712222656,
#    'id_str': '712222656',
#    'name': 'Gyra Barroga',
#    'screen_name': 'gyrabarroga',
#    'location': '',
#    'description': 'DLSU 🏹✯ | Ecclesiastes 3:11 | Be the best version you can be | 💌 gyra.barroga@yahoo.com',
#    'url': 'https://t.co/1og6a1fRGA',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/1og6a1fRGA',
#        'expanded_url': 'http://Instagram.com/gyrabarroga',
#        'display_url': 'Instagram.com/gyrabarroga',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 22257,
#    'friends_count': 436,
#    'listed_count': 48,
#    'created_at': 'Mon Jul 23 10:48:22 +0000 2012',
#    'favourites_count': 14488,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 18923,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '9266CC',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1084020576379760640/VU1YyAX1_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1084020576379760640/VU1YyAX1_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/712222656/1549508659',
#    'profile_link_color': '7F38EC',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '78C0A8',
#    'profile_text_color': '5E412F',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 4,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Feb 17 09:41:32 +0000 2019',
#   'id': 1097068520628674560,
#   'id_str': '1097068520628674560',
#   'text': 'RT @daddy_thom: ara galang is ara galang, jolina dela cruz deserves to have her own name too BUT CAN I JUST SAY DAMN THIS GIRL HAS THE MAKI…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'daddy_thom',
#      'name': '🕊',
#      'id': 562844484,
#      'id_str': '562844484',
#      'indices': [3, 14]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2976377922,
#    'id_str': '2976377922',
#    'name': '\U0001f9e1',
#    'screen_name': 'asdjkflpotatoez',
#    'location': '⚓',
#    'description': 'the sincerest form of apology is by not doing it again',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 685,
#    'friends_count': 2456,
#    'listed_count': 4,
#    'created_at': 'Mon Jan 12 10:05:13 +0000 2015',
#    'favourites_count': 130249,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 74361,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1096695880894169088/94El6rFg_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1096695880894169088/94El6rFg_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2976377922/1550307162',
#    'profile_link_color': '19CF86',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Feb 17 09:10:35 +0000 2019',
#    'id': 1097060730690387968,
#    'id_str': '1097060730690387968',
#    'text': 'ara galang is ara galang, jolina dela cruz deserves to have her own name too BUT CAN I JUST SAY DAMN THIS GIRL HAS… https://t.co/gNekLEPFCy',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/gNekLEPFCy',
#       'expanded_url': 'https://twitter.com/i/web/status/1097060730690387968',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [116, 139]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 562844484,
#     'id_str': '562844484',
#     'name': '🕊',
#     'screen_name': 'daddy_thom',
#     'location': '',
#     'description': 'fan account',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 6116,
#     'friends_count': 107,
#     'listed_count': 30,
#     'created_at': 'Wed Apr 25 10:15:31 +0000 2012',
#     'favourites_count': 53642,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 85311,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1097044457319362560/3_CYzwsr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1097044457319362560/3_CYzwsr_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/562844484/1523128715',
#     'profile_link_color': 'F5ABB5',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 106,
#    'favorite_count': 196,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 106,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Feb 17 09:41:31 +0000 2019',
#   'id': 1097068517084454912,
#   'id_str': '1097068517084454912',
#   'text': 'Ace by Dela Cruz \n#BlazeTheTrailDLSU',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'BlazeTheTrailDLSU',
#      'indices': [18, 36]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': []},
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 972000534671446016,
#    'id_str': '972000534671446016',
#    'name': 'BARJIE',
#    'screen_name': 'itsmebarj',
#    'location': '',
#    'description': 'Beauty is not found on me, but my personality brings you to remember me! • NDU • Nursing Student • Athlete',
#    'url': 'https://t.co/H129FDvODv',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/H129FDvODv',
#        'expanded_url': 'http://Instagram.com//barj.karim2',
#        'display_url': 'Instagram.com//barj.karim2',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1948,
#    'friends_count': 578,
#    'listed_count': 0,
#    'created_at': 'Fri Mar 09 06:46:01 +0000 2018',
#    'favourites_count': 9096,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 10909,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1094926314417532929/KvaJBi7K_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1094926314417532929/KvaJBi7K_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/972000534671446016/1544960208',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'es'},
#  {'created_at': 'Sun Feb 17 09:41:31 +0000 2019',
#   'id': 1097068515041804288,
#   'id_str': '1097068515041804288',
#   'text': 'RT @MissEverywhere_: Jolina Dela Cruz is the real deal.\n\n#BlazeTheTrailDLSU',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'BlazeTheTrailDLSU',
#      'indices': [57, 75]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'MissEverywhere_',
#      'name': 'For The Lady Spikers ➳',
#      'id': 708682892637904897,
#      'id_str': '708682892637904897',
#      'indices': [3, 19]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 3042846452,
#    'id_str': '3042846452',
#    'name': '𝐦𝐢𝐚 ✯',
#    'screen_name': 'blissfulasalle_',
#    'location': 'multi ☆彡 ph',
#    'description': 'fan account (mainly) for the green + white. #4LaSalleYan | #TIWALASALLE | #LetsDoDes!',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 376,
#    'friends_count': 403,
#    'listed_count': 8,
#    'created_at': 'Thu Feb 26 08:20:56 +0000 2015',
#    'favourites_count': 28479,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 9808,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1096628222278529024/hedSmo_e_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1096628222278529024/hedSmo_e_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3042846452/1550291519',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Feb 17 09:41:08 +0000 2019',
#    'id': 1097068421609652224,
#    'id_str': '1097068421609652224',
#    'text': 'Jolina Dela Cruz is the real deal.\n\n#BlazeTheTrailDLSU',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BlazeTheTrailDLSU',
#       'indices': [36, 54]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 708682892637904897,
#     'id_str': '708682892637904897',
#     'name': 'For The Lady Spikers ➳',
#     'screen_name': 'MissEverywhere_',
#     'location': 'De La Salle University',
#     'description': 'UAAP Best Libero | PSL Best Libero | UAAP MVP | PSL MVP | One of Asia’s finest | Miss Volleyball 2017 | Miss Everywhere 🇵🇭 @dawn_macandili',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 6606,
#     'friends_count': 341,
#     'listed_count': 19,
#     'created_at': 'Sat Mar 12 15:55:43 +0000 2016',
#     'favourites_count': 4280,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 5409,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1097000222184468482/Y7O7JRP1_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1097000222184468482/Y7O7JRP1_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/708682892637904897/1490092876',
#     'profile_link_color': '19CF86',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
# ...
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BlazeTheTrailDLSU',
#       'indices': [97, 115]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'tl', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 562844484,
#     'id_str': '562844484',
#     'name': '🕊',
#     'screen_name': 'daddy_thom',
#     'location': '',
#     'description': 'fan account',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 6116,
#     'friends_count': 107,
#     'listed_count': 30,
#     'created_at': 'Wed Apr 25 10:15:31 +0000 2012',
#     'favourites_count': 53642,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 85311,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1097044457319362560/3_CYzwsr_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1097044457319362560/3_CYzwsr_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/562844484/1523128715',
#     'profile_link_color': 'F5ABB5',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 44,
#    'favorite_count': 96,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'tl'},
#   'is_quote_status': False,
#   'retweet_count': 44,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'tl'},
#  {'created_at': 'Sun Feb 17 09:40:41 +0000 2019',
#   'id': 1097068305225986048,
#   'id_str': '1097068305225986048',
#   'text': 'RT @archerxlurker: Reminder sa toxic fans:\n-pwedeng ma-lotlot ang Lady Spikers\n-bago ang libero, give her a break\n-maraming rookies, temper…',
#   'truncated': False,
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'archerxlurker',
#      'name': 'Guinevere Beks',
#      'id': 888789873951293441,
#      'id_str': '888789873951293441',
#      'indices': [3, 17]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 713655956685479936,
#    'id_str': '713655956685479936',
#    'name': '❌reina pajas❌',
#    'screen_name': 'ilovegreenANIMO',
#    'location': 'Tuguegarao City, Cagayan Valle',
#    'description': 'CHOCOLATES🍫 AND PARK JIMIN 💛🐥 🙏🔜🔜CPA',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 286,
#    'friends_count': 276,
#    'listed_count': 0,
#    'created_at': 'Sat Mar 26 09:16:53 +0000 2016',
#    'favourites_count': 8604,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4497,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1096704530035687429/3WnSYuJe_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1096704530035687429/3WnSYuJe_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/713655956685479936/1546945104',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Feb 17 06:17:39 +0000 2019',
#    'id': 1097017211128958977,
#    'id_str': '1097017211128958977',
#    'text': 'Reminder sa toxic fans:\n-pwedeng ma-lotlot ang Lady Spikers\n-bago ang libero, give her a break\n-maraming rookies, t… https://t.co/uPWFbyebEb',
#    'truncated': True,
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/uPWFbyebEb',
#       'expanded_url': 'https://twitter.com/i/web/status/1097017211128958977',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 888789873951293441,
#     'id_str': '888789873951293441',
#     'name': 'Guinevere Beks',
#     'screen_name': 'archerxlurker',
#     'location': 'Taft Avenue, Manila',
#     'description': 'Rant space. Not the chatty type. Dilettante. Mystery and Macabre. So taken.',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1537,
#     'friends_count': 579,
#     'listed_count': 1,
#     'created_at': 'Sat Jul 22 15:56:33 +0000 2017',
#     'favourites_count': 11701,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 7380,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1003588121693380608/Js9EcnG6_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1003588121693380608/Js9EcnG6_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/888789873951293441/1522426321',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 68,
#    'favorite_count': 133,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 68,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Sun Feb 17 09:40:40 +0000 2019',
#   'id': 1097068304315801600,
#   'id_str': '1097068304315801600',
#   'text': 'Mayang 😍 #BlazeTheTrailDLSU',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'BlazeTheTrailDLSU', 'indices': [9, 27]}],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': []},
#   'metadata': {'iso_language_code': 'tl', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 3617523379,
#    'id_str': '3617523379',
#    'name': 'Dry',
#    'screen_name': 'patricksayy',
#    'location': 'Quezon City',
#    'description': '19',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 755,
#    'friends_count': 658,
#    'listed_count': 1,
#    'created_at': 'Sat Sep 19 15:58:45 +0000 2015',
#    'favourites_count': 9413,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 12058,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '0099B9',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1082073767940042752/0NVzKe50_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1082073767940042752/0NVzKe50_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3617523379/1529767668',
#    'profile_link_color': '19CF86',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'tl'},
#  {'created_at': 'Sun Feb 17 09:40:40 +0000 2019',
#   'id': 1097068300847050752,
#   'id_str': '1097068300847050752',
#   'text': 'RT @LSLadySpikers: SECOND TECHNICAL TIMEOUT\n16-15, DLSU. #BlazeTheTrailDLSU',
#   'truncated': False,
#   'entities': {'hashtags': [{'text': 'BlazeTheTrailDLSU',
#      'indices': [57, 75]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'LSLadySpikers',
#      'name': 'DLSU LADY SPIKERS',
#      'id': 723825479854104576,
#      'id_str': '723825479854104576',
#      'indices': [3, 17]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1028890660143681537,
#    'id_str': '1028890660143681537',
#    'name': 'lira',
#    'screen_name': 'ESTIL0',
#    'location': '🇵🇭',
#    'description': 'i want kimchi, lettuce, soy beans, and thin slice of pork = samgyeopsal 😋',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 111,
#    'friends_count': 276,
#    'listed_count': 1,
#    'created_at': 'Mon Aug 13 06:27:04 +0000 2018',
#    'favourites_count': 3472,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 4156,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1096773758096789504/4075TjKr_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1096773758096789504/4075TjKr_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1028890660143681537/1549937170',
#    'profile_link_color': '000000',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun Feb 17 09:40:10 +0000 2019',
#    'id': 1097068177790357504,
#    'id_str': '1097068177790357504',
#    'text': 'SECOND TECHNICAL TIMEOUT\n16-15, DLSU. #BlazeTheTrailDLSU',
#    'truncated': False,
#    'entities': {'hashtags': [{'text': 'BlazeTheTrailDLSU',
#       'indices': [38, 56]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 723825479854104576,
#     'id_str': '723825479854104576',
#     'name': 'DLSU LADY SPIKERS',
#     'screen_name': 'LSLadySpikers',
#     'location': '',
#     'description': "Avid supporter of green and white. Never Shall We Fail! ANIMO LA SALLE!\nest. since '16 but my green heart was born during Season 75.",
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 60,
#     'friends_count': 53,
#     'listed_count': 0,
#     'created_at': 'Sat Apr 23 10:46:57 +0000 2016',
#     'favourites_count': 2009,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 2308,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/723833173692444673/7FEHK_RA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/723833173692444673/7FEHK_RA_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/723825479854104576/1525265987',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 1,
#    'favorite_count': 0,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 1,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'}]

# %% [markdown]
# twitter often returns duplicate records, we will filter them out checking for duplicate texts

# %%
all_text_in_world = []
filtered_statuses_in_world = []
for s in statuses_in_world:
    if not s["text"] in all_text_in_world:
        filtered_statuses_in_world.append(s)
        all_text_in_world.append(s["text"])
len(filtered_statuses_in_world)
# Out:
# 86

# %% [markdown]
# This mean from 100(number) record 14 were duplicates 100-14=86

# %% [markdown]
# Now we are executing a search on Twitter for the most popular trend and filtering step to remove duplicate results.
#
# Setting the `topic` variable to the most popular trend in the list we retrieved in list_of_trends:-

# %%
topic = list_of_trends[0]  # 1st element in list_of_trends
number = 100   #number of records you want to get, here=100

search_results = twitter_api.search.tweets(q=topic, count=number)

statuses = search_results['statuses']

# %%
#print(statuses)   #it will print all the metadata(bunch of record in JSON format) of the topic trend

# %% [markdown]
# twitter often returns duplicate records, we will filter them out checking for duplicate text smiliarly as done above

# %%
all_text = []
filtered_statuses = []
for s in statuses:
    if not s["text"] in all_text:
        filtered_statuses.append(s)
        all_text.append(s["text"])
len(filtered_statuses)
# Out:
# 79

# %% [markdown]
# This mean from 100(number) record 21 were duplicates 100-21=79

# %% [markdown]
# ## Creating a list of retweet count and status tuples
#
# We want to sort the tweets by the retweet count, therefore the first step is to create a list of tuples where the first element is the retweet count and then use the `sorted` function to perform the sorting operation.

# %%
retweets_world = [(s["retweet_count"], s["text"]) for s in filtered_statuses_in_world]
retweets = [(s["retweet_count"], s["text"]) for s in filtered_statuses]

# %%
popular_tweets_world = sorted(retweets_world, reverse=True)[:10] #10 most popular or first 10
popular_tweets = sorted(retweets, reverse=True)[:10]

# %% [markdown]
# 10 most popular retweets in world:-

# %%
popular_tweets_world
# Out:
# [(411,
#   'RT @MissEverywhere_: Why #BlazeTheTrailDLSU?\n\nPlayers come and go. This year, we witness the rise of new and young players ready to make th…'),
#  (256,
#   'RT @MissEverywhere_: This is your year, Captain.\n\n#BlazeTheTrailDLSU\n#LetsDoDes https://t.co/85wREYJj3Z'),
#  (171,
#   'RT @daddy_thom: jolina dela cruz wearing jersey 8 and that hairstyle! little ara galang? 😳 U! W! U! 💗💕💓💘 #BlazeTheTrailDLSU https://t.co/dG…'),
#  (106,
#   'RT @daddy_thom: ara galang is ara galang, jolina dela cruz deserves to have her own name too BUT CAN I JUST SAY DAMN THIS GIRL HAS THE MAKI…'),
#  (80,
#   'RT @VolleyBasher: Jolina Dela Cruz!!! Lakas ni bakla!!! Mukhang may another challenger na si Eya Laure sa Rookie of the Year award. Loveett…'),
#  (69,
#   'RT @macramos_81: One Last Ride to our Captain\n@itsmedescheng \n\n#BlazeTheTrailDLSU https://t.co/aYFvd7OCK0'),
#  (68,
#   'RT @archerxlurker: Reminder sa toxic fans:\n-pwedeng ma-lotlot ang Lady Spikers\n-bago ang libero, give her a break\n-maraming rookies, temper…'),
#  (57,
#   'RT @yeyeaddicts: Jolina De La Cruz, making her name known! Grabe 💚 #BlazeTheTrailDLSU'),
#  (56,
#   'RT @VolleyBasher: Lavarn si Ogunsanya!! Galing ni bakla. Girl on fire. Ayun nasunog. Chaaarrrr. Pakagaling ni coach Ramil magproduce ng mid…'),
#  (52,
#   'RT @daddy_thom: OKAY DONT GET ME WRONG GUYS DI NAMAN SA NAGCOCOMPARE AKO PERO SHET NAKAKA EXCITE LANG KASI AT NAKAKATUWA PANOORIN SI JOLINA…')]

# %% [markdown]
# 10 most popular retweets for local area(jaipur):-

# %%
popular_tweets
# Out:
# [(1895,
#   'RT @DrKumarVishwas: No need to #ExposeDeshDrohis They have a habit to expose themselves time to time ! Just mark them and finish their hein…'),
#  (1174,
#   "RT @MODIfiedVikas: Watch out for such trouble makers. Already a saffron clad 'rioter' is being made villian ( cartoon by Mr. Mansoor @carto…"),
#  (1153,
#   'RT @_LordZilla_: Do expect the next video on Adil Ahmed Dar to be released soon from the factory of #UrbanNaxals. How innocent he was, a cr…'),
#  (812,
#   'RT @IAMNiraj_singh: Dear @iitmadras this Assh*le has made Mockery of Pulwama Terror Attack which caused lives of 44 CRPF Jawans . Take acti…'),
#  (645,
#   'RT @Engihumor: Hi @DelhiPolice @DCP_CCC_Delhi, this account from JNU is spreading fake news about Kashmiris being trapped in a hostel to in…'),
#  (516,
#   'RT @SwamiGeetika: "I don\'t want to waste my time talking about them."\nMajor @generalbakshi exposes the hypocrisy of Navjpt Singh Sidhu,Mehb…'),
#  (454,
#   'RT @abhijitmajumder: ALERT! After fake news over #KashmiriStudents, now scaremongering afoot in LGBTQ groups that gay, lesbians are suddenl…'),
#  (334,
#   "RT @Ankita_Shah8: NSA Ajit doval's son is doing business with Pakistan, He is the one who should be called Deshdrohi.\n\n#ExposeDeshDrohis"),
#  (331,
#   'RT @Shankar31256159: Where are they now???\n#ExposeDeshDrohis https://t.co/3WHJm4ux2T'),
#  (311,
#   'RT @ShobhaBJP: GOI taking swift actions against the #PulwamaAttack masterminds.\n\n- MFN revoked\n- Customs duty on all goods imported from Pa…')]
